# %% [markdown]
# #Set Assignments

# %% [markdown]
# 1. Add a list of elements to a given set
# Given:
# sampleSet = {"Yellow", "Orange", "Black"}
# sampleList = ["Blue", "Green", "Red",”Yellow”,”orange”]

# %%
sampleSet = {"Yellow", "Orange", "Black"}
sampleList = ["Blue", "Green", "Red",'Yellow','orange']
ssl=list(sampleSet)
ssl.extend(sampleList)
ssl
# Out:
# ['Yellow', 'Black', 'Orange', 'Blue', 'Green', 'Red', 'Yellow', 'orange']

# %%
sampleSet = {"Yellow", "Orange", "Black"}
sampleList = ["Blue", "Green", "Red",'Yellow','orange']
sampleSet.update(sampleList)
print(sampleSet)
result=sampleSet.union(sampleList)
result
# Out:
# {'Green', 'Blue', 'Orange', 'Yellow', 'orange', 'Black', 'Red'}
# {'Black', 'Blue', 'Green', 'Orange', 'Red', 'Yellow', 'orange'}

# %% [markdown]
# 2. display common elements from the given set
# set1 = {10, 20, 30, 40, 50}
# set2 = {30, 40, 50, 60, 70}

# %%
set3 = {10, 20, 30, 40, 50}
set4 = {30, 40, 50, 60, 70}

print(set3.intersection(set4))
print(set3 & set4 )
# Out:
# {40, 50, 30}
# {40, 50, 30}

# %% [markdown]
# 3. Generate a new set with all items from both sets by removing numbers which are in both sets.
# set1 = {10, 20, 30, 40, 50,25}
# set2 = {30, 40, 50, 60, 70,100}
# o/p : order is not important
# {70, 10, 20, 60,25,100}

# %%
 set5 = {10, 20, 30, 40, 50 , 25 }
 set6 = {30, 40, 50, 60, 70, 100 }
set5 ^ set6
# Out:
# {10, 20, 25, 60, 70, 100}

# %% [markdown]
# 4. set of all elements in either A or B, but not both
# set1 = {10, 20, 30, 40, 50}
# set2 = {30, 40, 50, 60, 70}
# Expected output:
# {20, 70, 10, 60}

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}
set1 ^ set2
# Out:
# {10, 20, 60, 70}

# %% [markdown]
# 5. Update set1 by adding items from set2, except common items
# set1 = {10, 20, 30, 40, 50}
# set2 = {30, 40, 50, 60, 70}
# Expected output:
# {70, 10, 20, 60}

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}
set1=set1 ^ set2
set1
# Out:
# {10, 20, 60, 70}

# %% [markdown]
# 6. Take a sentence as input from user. Every word is seperated by space. Print all unique words from the sentence.

# %%
s='my name is prajwal and prajwal loves to swim'
l=s.split(" ")
l=set(l)
l
# Out:
# {'and', 'is', 'loves', 'my', 'name', 'prajwal', 'swim', 'to'}

# %% [markdown]
# count the word in sentence

# %%
s='my name is prajwal and prajwal is a bad boy'
wcnt=0
s=s.split()
wc = {}

for word in s:
  if word in wc:
    wc[word]+=1
  else:
    wc[word]=1

wc
for i,j in wc.items():
  if j==1:
    print(i,j)
# Out:
# my 1
# name 1
# and 1
# a 1
# bad 1
# boy 1

# %% [markdown]
# #Tuple Assignment

# %% [markdown]
# 1. Reverse the following tuple
# aTuple = (10, 20, 30, 40, 50,60)
# Expected output:
# (60,50, 40, 30, 20, 10)

# %%
Tuple = (10, 20, 30, 40, 50,60)
Tuple[::-1]
# Out:
# (60, 50, 40, 30, 20, 10)

# %%
set1 = (10, 20, 30, 40, 50 , 60)
print(set1[::-1])
# Out:
# (60, 50, 40, 30, 20, 10)

# %% [markdown]
# 2. display value 20 from the following tuple
# aTuple = ("Orange", [10, 20, 30], (5, 15, 25))

# %%
Tuple = ("Orange", [10, 20, 30], (5, 15, 25))
Tuple[1][1]
# Out:
# 20

# %% [markdown]
# 3. Unpack the following tuple into 4 variables
# aTuple = (10, 20, 30, 40)

# %%
Tuple = (10, 20, 30, 40)
a,b,c,d=Tuple
print(a,b,c,d)
# Out:
# 10 20 30 40

# %% [markdown]
# 4. Swap the following two tuples
# tuple1 = (11, 22)
# tuple2 = (99, 88)
# Expected output:
# tuple1 = (99, 88)
# tuple2 = (11, 22)

# %%
tuple1 = (11, 22)
tuple2 = (99, 88)

tuple1,tuple2=tuple2,tuple1
print(tuple1)
print(tuple2)
# Out:
# (99, 88)
# (11, 22)

# %% [markdown]
# 5. Copy element 44 and 55 from the following tuple into a new tuple
# tuple1 = (11, 22, 33, 44, 55, 66)
# Expected output:
# tuple2: (44, 55)

# %%
tuple1 = (11, 22, 33, 44, 55, 66)
new_tuple=(x for x in tuple1 if x==44 or x==55)
tuple(new_tuple)
# Out:
# (44, 55)

# %% [markdown]
# 6. Modify the first item (22) of a list inside a following tuple to 200
# tuple1 = (11, [22, 33], 44, 55)
# Expected output:
# tuple1: (11, [200, 33], 44, 55)

# %%
tuple1 = (11, [22, 33], 44, 55)
tuple1[1][0]=200
tuple1
# Out:
# (11, [200, 33], 44, 55)

# %% [markdown]
# 7. Take two integer values in a & b. Swap their values using tuple, using temparary variable and without tuple and without temparary variable.
# Ex. a=10 b=23
# After swapping a=23 b=10

# %%
a=10
b=23
b,a=(a,b)
print(a,b)
# Out:
# 23 10

# %% [markdown]
# #Dictionary Assignments

# %% [markdown]
# 2. Given a dictionary of students and their favourite colours:
# people={'Arham':'Blue','Lisa':'Yellow',''Vinod:'Purple','Jenny':'Pink'}
# a. Find out how many students are in the list
# b. Change Lisa’s favourite colour
# c. Remove 'Jenny' and her favourite colour

# %%
people={'Arham':'Blue','Lisa':'Yellow','Vinod':'Purple','Jenny':'Pink'}
for i in people:
  print(i,end=" ")
# Out:
# Arham Lisa Vinod Jenny

# %%
people['Lisa']='black'

# %%
#new_people=people.pop('Jenny')
people
# Out:
# {'Arham': 'Blue', 'Lisa': 'black', 'Vinod': 'Purple', 'Jenny': 'Pink'}

# %% [markdown]
# 5. Take a sentence as input from user. Every word is seperated by space.
# a. Create a word_count dictionary which will have unique words and their count.

# %%
string='A regression is A statistical technique that relates a dependent variable to one or more'
lstring=string.lower().split()
wc={}
for word in lstring:
  if word in wc:
    wc[word]+=1
  else:
    wc[word]=1

for i,j in wc.items():
  if j==1:
    print(i,":",j,end=" , ")
# Out:
# regression : 1 , is : 1 , statistical : 1 , technique : 1 , that : 1 , relates : 1 , dependent : 1 , variable : 1 , to : 1 , one : 1 , or : 1 , more : 1 ,

# %% [markdown]
# b. create suffix_count dictionary which will contain count of words ending with 's', 'es', 'ed', 'y', 'en' , etc.

# %%
import re
suffix_count={}
string='A regression is A statistical technique that relates a dependent variable to one or more'

# for word in string:
#   if word.endswith('s'):
#     suffix_count[word]+=1
#     break
#   elif word.endswith("es"):
#     suffix_count[word]+=1
#     break
#   elif word.endswith("ed"):
#     suffix_count[word]+=1
#     break
#   elif word.endswith("y"):
#     suffix_count[word]+=1
#     break
#   elif word.endswith("en"):
#     suffix_count[word]+=1



for word in string:
    print(word)
# Out:
# A
#
# r
# e
# g
# r
# e
# s
# s
# i
# o
# n
#
# i
# s
#
# A
#
# s
# t
# a
# t
# i
# s
# t
# i
# c
# a
# l
#
# t
# e
# c
# h
# n
# i
# q
# u
# e
#
# t
# h
# a
# t
#
# r
# e
# l
# a
# t
# e
# s
#
# a
#
# d
# e
# p
# e
# n
# d
# e
# n
# t
#
# v
# a
# r
# i
# a
# b
# l
# e
#
# t
# o
#
# o
# n
# e
#
# o
# r
#
# m
# o
# r
# e
